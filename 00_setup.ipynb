# %%
# !pip install -q -r https://raw.githubusercontent.com/davidordoez29/mvp-tarjetas-chile/main/requirements.txt
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.0/25.0 MB 51.1 MB/s eta 0:00:00

# %%
import pandas as pd, numpy as np
import sklearn, xgboost, lightgbm, statsmodels, lifelines
import ortools, pulp, cvxpy, streamlit, plotly

print("✅ Todo importado correctamente, el entorno está listo.")
# Out:
# ✅ Todo importado correctamente, el entorno está listo.

# %%
import sys, platform
print("Python version:", sys.version)
print("Platform:", platform.platform())
# Out:
# Python version: 3.12.11 (main, Jun  4 2025, 08:56:18) [GCC 11.4.0]
# Platform: Linux-6.1.123+-x86_64-with-glibc2.35
